# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()

xi_values = np.array([(2)**(1/2), 2, (8)**(1/2), (18)**(1/2)])
eta_values = np.array([(2)**(1/2), 2, (8)**(1/2), (18)**(1/2)])
y_values = np.linspace(-20, 20, 1000)

for xi in xi_values:
    x = (xi**2 - (y_values / xi)**2) / 2
    ax.plot(x, y_values, color='red') 

for eta in eta_values:
    x = ((y_values / eta)**2 - eta**2) / 2
    ax.plot(x, y_values, color='green')  

circles = [plt.Circle((0, 0), radius, color='black', fill=False, linestyle='--', linewidth=1.3) for radius in [1, 2, 4, 9]]
for circle in circles:
    ax.add_artist(circle)

ax.text(7.5, 10,  r'$\xi=\sqrt{2}$' , fontsize=6, ha='center')
ax.text(-1.5, 10.5,  r'$\xi=2$' , fontsize=6, ha='center')
ax.text(-8.5, 10,  r'$\xi=2\sqrt{2}$' , fontsize=6, ha='center')
ax.text(-10, 7.5,  r'$\xi=3\sqrt{2}$' , fontsize=6, ha='center')
ax.text(-7.7, -10.5,  r'$\eta=\sqrt{2}$' , fontsize=6, ha='center')
ax.text(1.5, -10.5,  r'$\eta=2$' , fontsize=6, ha='center')
ax.text(8.5, -10.5,  r'$\eta=2\sqrt{2}$' , fontsize=6, ha='center')
ax.text(10, -7.9,  r'$\eta=3\sqrt{2}$' , fontsize=6, ha='center')



ax.axhline(0, color='black', linestyle='-')  
ax.axvline(0, color='black', linestyle='-')  
ax.set_aspect('equal')
ax.set_xlim([-11, 11])
ax.set_ylim([-11, 11])
ax.grid(False)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.tick_params(axis='x', colors='black', labelsize=5)
ax.tick_params(axis='y', colors='black', labelsize=5)
plt.title(r'Quadratic Parabolic Coordinates')


plt.savefig('plot.png', dpi=300)  

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()

xi_values = np.array([(2)**(1/2), 2,(8)**(1/2), (18)**(1/2)])
xi_values_grid = np.array([(32)**(1/2), (50)**(1/2)])
eta_values = np.array([(2)**(1/2),2, (8)**(1/2), (18)**(1/2)])
eta_values_grid = np.array([(32)**(1/2),(50)**(1/2)])
y_values = np.linspace(-20, 20, 1000)

for xi in xi_values:
    x = (xi - (y_values**2) / (2*xi)) / 2**(1/2)
    ax.plot(x, y_values, color='red')  

for eta in eta_values:
    x = ((y_values**2) / (2*eta) - eta) / 2**(1/2)
    ax.plot(x, y_values, color='green')  

for xi in xi_values_grid:
    x = (xi - (y_values**2) / (2*xi)) / 2**(1/2)
    ax.plot(x, y_values, color=grid_color_rgb)  

for eta in eta_values_grid:
    x = ((y_values**2) / (2*eta) - eta) / 2**(1/2)
    ax.plot(x, y_values, color=grid_color_rgb)      

ax.axhline(0, color='black', linestyle='-')  
ax.axvline(0, color='black', linestyle='-')  

ax.set_aspect('equal')
ax.set_xlim([-7, 7])
ax.set_ylim([-7, 7])

ax.grid(False)
circles = [plt.Circle((0, 0), radius, color='black', fill=False, linestyle=':',linewidth=1.4) for radius in [1, 2, 4]]
for circle in circles:
    ax.add_artist(circle)
    ax.text(circle.radius / np.sqrt(2), circle.radius / np.sqrt(2), r'$\rho={}$'.format(circle.radius), 
    color='black', fontsize=6, ha='left', va='bottom')

ax.spines['left'].set_position('zero')
ax.spines['left'].set_color('black')
ax.spines['left'].set_linewidth(0.5)

ax.text(-1.8,6.7,  r'$\xi=\sqrt{2}$' , fontsize=5.5, ha='center')
ax.text(-3.9, 6.25,  r'$\xi=2$' , fontsize=5.5, ha='center')
ax.text(-4.9, 5.28,  r'$\xi=2\sqrt{2}$' , fontsize=5.5, ha='center')
ax.text(-5.9, 4.5,  r'$\xi=3\sqrt{2}$' , fontsize=5.5, ha='center')
ax.text(5.7, -4.8,  r'$\eta=\sqrt{2}$' , fontsize=6, ha='center')
ax.text(4.6, -5.5,  r'$\eta=2$' , fontsize=6, ha='center')
ax.text(2.8, -5.7,  r'$\eta=2\sqrt{2}$' , fontsize=6, ha='center')
ax.text(1, -6.2,  r'$\eta=3\sqrt{2}$' , fontsize=6, ha='center')

ax.spines['bottom'].set_position('zero')
ax.spines['bottom'].set_color('black')
ax.spines['bottom'].set_linewidth(0.5)

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.tick_params(axis='x', colors='black', labelsize=6)
ax.tick_params(axis='y', colors='black', labelsize=6)
plt.title("Linear Parabolic Coordinates")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()

xi_values = np.array([(2)**(1/2), 2,(8)**(1/2), (18)**(1/2)])
xi_values_grid = np.array([ (50)**(1/2),(72)**(1/2)])
eta_values = np.array([(2)**(1/2),2, (8)**(1/2), (18)**(1/2)])
eta_values_grid = np.array([(50)**(1/2), (72)**(1/2)])
y_values = np.linspace(-20, 20, 1000)

for xi in xi_values:
    x = (xi - (y_values**2) / (2*xi)) / 2**(1/2)
    ax.plot(x, y_values, color='red')  

for eta in eta_values:
    x = ((y_values**2) / (2*eta) - eta) / 2**(1/2)
    ax.plot(x, y_values, color='green')  

for xi in xi_values_grid:
    x = (xi - (y_values**2) / (2*xi)) / 2**(1/2)
    ax.plot(x, y_values, color=grid_color_rgb)  

for eta in eta_values_grid:
    x = ((y_values**2) / (2*eta) - eta) / 2**(1/2)
    ax.plot(x, y_values, color=grid_color_rgb)      

ax.axhline(0, color='black', linestyle='-')  
ax.axvline(0, color='black', linestyle='-')  

ax.set_aspect('equal')
ax.set_xlim([-4, 4])
ax.set_ylim([-4, 4])

ax.grid(False)
circles = [plt.Circle((0, 0), radius, color='black', fill=False, linestyle=':',linewidth=1.4) for radius in [1, (2)**(1/2), 2, 3]]
for circle in circles:
    ax.add_artist(circle)
    ax.text(circle.radius / np.sqrt(2), circle.radius / np.sqrt(2), r'$\rho={}$'.format(circle.radius), 
    color='black', fontsize=6, ha='left', va='bottom')

ax.spines['left'].set_position('zero')
ax.spines['left'].set_color('black')
ax.spines['left'].set_linewidth(0.5)

ax.spines['bottom'].set_position('zero')
ax.spines['bottom'].set_color('black')
ax.spines['bottom'].set_linewidth(0.5)

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.tick_params(axis='x', colors='black', labelsize=6)
ax.tick_params(axis='y', colors='black', labelsize=6)
plt.title("Linear Parabolic Coordinates")

plt.show()
